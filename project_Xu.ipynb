# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
donnees = gpd.read_file('D:/学习2/CPS先进数据分析/qimo/2024-project/donnees-bruit-nuit.zip')
ic_act_path = 'D:/学习2/CPS先进数据分析/qimo/iris-statistiques/Csv/ic_act_2016.csv'
ic_act = pd.read_csv(ic_act_path, sep=';',encoding='latin1')
# Out:
# C:\Users\99166\AppData\Local\Temp\ipykernel_13536\1188890454.py:3: DtypeWarning: Columns (0,2,3,4,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   ic_act = pd.read_csv(ic_act_path, sep=';',encoding='latin1')

# %%
donnees.sample(1)
# Out:
#       objectid theme source  gridcode  from  to period  \
# 1846  929300.0  NUIT  MULTI      50.0   NaN NaN   None
#
#                                                geometry
# 1846  POLYGON ((3.18367 50.68244, 3.18367 50.68249, ...

# %%
print(type(donnees))
print(type(ic_act))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
mel_cities = gpd.read_file('D:/学习2/CPS先进数据分析/qimo/2024-project/cartographic-resources/mel_communes.zip')
nordData = gpd.read_file('D:/学习2/CPS先进数据分析/qimo/2024-project/cartographic-resources/IRIS-GE_2-0_SHP_LAMB93_D059-2020/IRIS_GE.SHX')

lilleMetropolis = nordData[nordData.INSEE_COM.isin(mel_cities['insee']) ]


ok = ic_act[ic_act.INSEE_COM.isin(lilleMetropolis['CODE_IRIS']) ]

ok.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13536\1829192326.py in ?()
#       1 mel_cities = gpd.read_file('D:/学习2/CPS先进数据分析/qimo/2024-project/cartographic-resources/mel_communes.zip')
#       2 nordData = gpd.read_file('D:/学习2/CPS先进数据分析/qimo/2024-project/cartographic-resources/IRIS-GE_2-0_SHP_LAMB93_D059-2020/IRIS_GE.SHX')
#       3
#       4 lilleMetropolis = nordData[nordData.INSEE_COM.isin(mel_cities['insee']) ]
# ----> 5 ic_act.column
#       6
#
# d:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# ...

# %%
print(ic_act.columns)
print(ic_act.shape)
ic_act.plot()
# Out:
# Index(['IRIS', 'REG', 'DEP', 'UU2010', 'COM', 'LIBCOM', 'TRIRIS', 'GRD_QUART',
#        'LIBIRIS', 'TYP_IRIS',
#        ...
#        'P16_ACTOCC15P_ILT2', 'P16_ACTOCC15P_ILT3', 'P16_ACTOCC15P_ILT4',
#        'P16_ACTOCC15P_ILT5', 'C16_ACTOCC15P', 'C16_ACTOCC15P_PAS',
#        'C16_ACTOCC15P_MAR', 'C16_ACTOCC15P_DROU', 'C16_ACTOCC15P_VOIT',
#        'C16_ACTOCC15P_TCOM'],
#       dtype='object', length=114)
# (49653, 114)
# <Axes: >

# %%
print(ic_act.head())
# Out:
#        IRIS   REG DEP UU2010   COM                   LIBCOM  TRIRIS GRD_QUART  \
# 0  10010000  84.0   1   1000  1001  L'Abergement-Clémenciat  ZZZZZZ    100100
# 1  10020000  84.0   1   1000  1002    L'Abergement-de-Varey  ZZZZZZ    100200
# 2  10040101  84.0   1   1302  1004        Ambérieu-en-Bugey  ZZZZZZ    100401
# 3  10040102  84.0   1   1302  1004        Ambérieu-en-Bugey  ZZZZZZ    100401
# 4  10040201  84.0   1   1302  1004        Ambérieu-en-Bugey  ZZZZZZ    100402
#
#                                         LIBIRIS TYP_IRIS  ...  \
# 0  L'Abergement-Clémenciat (commune non irisée)        Z  ...
# 1    L'Abergement-de-Varey (commune non irisée)        Z  ...
# 2              Les Perouses-Triangle d'Activité        H  ...
# 3                                 Longeray-Gare        H  ...
# 4                   Centre-St Germain-Vareilles        H  ...
#
#    P16_ACTOCC15P_ILT2 P16_ACTOCC15P_ILT3  P16_ACTOCC15P_ILT4  \
# ...

# %%
print(donnees[donnees['P16_POP1564'] == 'NUIT'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File d:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'P16_POP1564'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import os

folder_path = 'D:/学习2/CPS先进数据分析/qimo/2024-project/cartographic-resources/IRIS-GE_2-0_SHP_LAMB93_D059-2020'
try:
    files = os.listdir(folder_path)
    for file in files:
        print(file)
except FileNotFoundError:
    print(f"The specified folder '{folder_path}' does not exist.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# IRIS_GE.CPG
# IRIS_GE.DBF
# IRIS_GE.PRJ
# IRIS_GE.SHP
# IRIS_GE.SHX
# LISTE.csv
